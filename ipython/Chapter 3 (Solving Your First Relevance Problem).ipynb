# %% [markdown]
# # Boilerplate Setup

# %%
import requests
import json


headers = {'Content-Type': 'application/json'};

# Optional, enable client-side caching for TMDB
# Requires: https://httpcache.readthedocs.org/en/latest/
#from httpcache import CachingHTTPAdapter
#tmdb_api.mount('https://', CachingHTTPAdapter())
#tmdb_api.mount('http://', CachingHTTPAdapter())

# Some utilities for flattening the explain into something a bit more
# readable. Pass Explain JSON, get something readable (ironically this is what Solr's default output is :-p)
def flatten(l):
    [item for sublist in l for item in sublist]

def simplerExplain(explainJson, depth=0):
    result = " " * (depth * 2) + "%s, %s\n" % (explainJson['value'], explainJson['description'])
    #print json.dumps(explainJson, indent=True)
    if 'details' in explainJson:
        for detail in explainJson['details']:
            result += simplerExplain(detail, depth=depth+1)
    return result

# %% [markdown]
# # 3.2.2 Indexing TMDB Movies

# %%
def extract():
    f = open('tmdb.json')
    if f:
         return json.loads(f.read());        
    return {}

# %%
def reindex(analysisSettings={}, mappingSettings={}, movieDict={}):
    settings = { #A
        "settings": {
            "number_of_shards": 1, #B
            "index": {
                "analysis" : analysisSettings, #C
            }}}

    if mappingSettings:
        settings['mappings'] = mappingSettings #C

    resp = requests.delete("http://localhost:9200/tmdb") #D
    resp = requests.put("http://localhost:9200/tmdb", 
                        data=json.dumps(settings),headers=headers)

    bulkMovies = ""
    print "building..."
    for id, movie in movieDict.iteritems(): 
        addCmd = {"index": {"_index": "tmdb", #E
                            "_type": "movie",
                            "_id": movie["id"]}}
        bulkMovies += json.dumps(addCmd) + "\n" + json.dumps(movie) + "\n"

    print "indexing..."
    resp = requests.post("http://localhost:9200/_bulk", data=bulkMovies, headers=headers)

# %%
movieDict = extract()
reindex(movieDict=movieDict)
# Out:
# building...
# indexing...

# %%
# Out:
# {
#  "poster_path": "/6diHusTm8eQJnfoI7MyCSDgaBRp.jpg",
#  "production_countries": [
#   {
#    "iso_3166_1": "AU",
#    "name": "Australia"
#   },
#   {
#    "iso_3166_1": "US",
#    "name": "United States of America"
#   }
#  ],
#  "revenue": 23006849,
#  "overview": "Two teenage girls discover a mermaid in their beach club's swimming pool.",
#  "video": false,
#  "id": 14191,
#  "genres": [
#   {
#    "id": 35,
#    "name": "Comedy"
#   },
#   {
#    "id": 14,
#    "name": "Fantasy"
#   },
#   {
#    "id": 10749,
#    "name": "Romance"
#   },
#   {
#    "id": 10751,
#    "name": "Family"
#   }
#  ],
#  "title": "Aquamarine",
#  "tagline": "A Fish-Out-Of-Water Comedy.",
#  "vote_count": 59,
#  "homepage": "http://www.aquamarinemovie.com/",
#  "belongs_to_collection": null,
#  "original_language": "en",
#  "status": "Released",
#  "spoken_languages": [
#   {
#    "iso_639_1": "en",
#    "name": "English"
#   }
#  ],
#  "imdb_id": "tt0429591",
#  "adult": false,
#  "backdrop_path": "/6LN4NJfNWzpJMcfzfqplsm8lVfe.jpg",
#  "production_companies": [
#   {
#    "name": "Storefront Pictures",
#    "id": 7747
#   },
#   {
#    "name": "20th Century Fox",
#    "id": 25
#   }
#  ],
#  "release_date": "2006-03-03",
#  "popularity": 0.340685029867431,
#  "original_title": "Aquamarine",
#  "budget": 12000000,
#  "cast": [
#   {
#    "name": "Emma Roberts",
#    "character": "Claire",
#    "order": 0,
#    "cast_id": 1,
#    "credit_id": "52fe45d59251416c750640ed",
#    "profile_path": "/yzf0nMrsxf1LjeFtoIw6Qwh7GpG.jpg",
#    "id": 34847
#   },
#   {
#    "name": "Joanna 'JoJo' Levesque",
#    "character": "Hailey",
#    "order": 1,
#    "cast_id": 2,
#    "credit_id": "52fe45d59251416c750640f1",
#    "profile_path": "/vKGPm1Y7H39mfIc2kSAUnCZRCMm.jpg",
#    "id": 57855
#   },
#   {
#    "name": "Sara Paxton",
#    "character": "Aquamarine",
#    "order": 2,
#    "cast_id": 3,
#    "credit_id": "52fe45d59251416c750640f5",
#    "profile_path": "/6tgy3NOeP2Cd1NiW9xHETQSbfvB.jpg",
#    "id": 60072
#   },
#   {
#    "name": "Jake McDorman",
#    "character": "Raymond",
#    "order": 3,
#    "cast_id": 4,
#    "credit_id": "52fe45d59251416c750640f9",
#    "profile_path": "/7DHDZrBne3diRwoWirg9djgKzTg.jpg",
#    "id": 94791
#   },
#   {
#    "name": "Arielle Kebbel",
#    "character": "Cecilia Banks",
#    "order": 4,
#    "cast_id": 5,
#    "credit_id": "52fe45d59251416c750640fd",
#    "profile_path": "/2uYMvWYDjRw7Kc0Ev7hK5PqTldd.jpg",
#    "id": 20373
#   },
#   {
#    "name": "Claudia Karvan",
#    "character": "Ginny",
#    "order": 5,
#    "cast_id": 6,
#    "credit_id": "52fe45d59251416c75064101",
#    "profile_path": "/8o2xMWxL9SkkxXrJOGI8THZhS8Q.jpg",
#    "id": 79966
#   },
#   {
#    "name": "Bruce Spence",
#    "character": "Leonard",
#    "order": 6,
#    "cast_id": 7,
#    "credit_id": "52fe45d59251416c75064105",
#    "profile_path": "/pwJJBmO9MG3OxVX9efGrB6BTFyw.jpg",
#    "id": 27752
#   },
#   {
#    "name": "Tammin Sursok",
#    "character": "Marjorie",
#    "order": 7,
#    "cast_id": 8,
#    "credit_id": "52fe45d59251416c75064109",
#    "profile_path": "/ghyiaX0upZev0shZcQ0OuE5AZ8y.jpg",
#    "id": 94792
#   },
#   {
#    "name": "Roy Billing",
#    "character": "Grandpa Bob",
#    "order": 8,
#    "cast_id": 9,
#    "credit_id": "52fe45d59251416c7506410d",
#    "profile_path": "/4fnmZ3ANu7KcjsOizlzNPjWQSpm.jpg",
#    "id": 94793
#   },
#   {
#    "name": "Julia Blake",
#    "character": "Grandma Maggie",
#    "order": 9,
#    "cast_id": 10,
#    "credit_id": "52fe45d59251416c75064111",
#    "profile_path": null,
#    "id": 77561
#   },
#   {
#    "name": "Shaun Micallef",
#    "character": "Storm Banks",
#    "order": 10,
#    "cast_id": 11,
#    "credit_id": "52fe45d59251416c75064115",
#    "profile_path": "/lqi9p3oMrcM3oIlWPC6qYyW6qgw.jpg",
#    "id": 75949
#   },
#   {
#    "name": "Lulu McClatchy",
#    "character": "Bonnie",
#    "order": 11,
#    "cast_id": 12,
#    "credit_id": "52fe45d59251416c75064119",
#    "profile_path": null,
#    "id": 94795
#   },
#   {
#    "name": "Natasha Cunningham",
#    "character": "Patty",
#    "order": 12,
#    "cast_id": 13,
#    "credit_id": "52fe45d59251416c7506411d",
#    "profile_path": null,
#    "id": 94796
#   },
#   {
#    "name": "Dichen Lachman",
#    "character": "Beth-Ann",
#    "order": 13,
#    "cast_id": 14,
#    "credit_id": "52fe45d59251416c75064121",
#    "profile_path": "/3Z4qUhsXxXhjVGX5bEecoty7H1n.jpg",
#    "id": 94797
#   },
#   {
#    "name": "Lincoln Lewis",
#    "character": "Theo",
#    "order": 14,
#    "cast_id": 15,
#    "credit_id": "52fe45d59251416c75064125",
#    "profile_path": "/lvvMmWd4Xx4FBDO6uXuLdLVGbHv.jpg",
#    "id": 94798
#   },
#   {
#    "name": "Joey Massey",
#    "character": "Little Boy",
#    "order": 15,
#    "cast_id": 20,
#    "credit_id": "52fe45d59251416c75064141",
#    "profile_path": "/vo8VTfp9nUTx3xtvdWRIq0YhrpQ.jpg",
#    "id": 1115764
#   }
#  ],
#  "directors": [
#   {
#    "name": "Elizabeth Allen",
#    "credit_id": "52fe45d59251416c7506412b",
#    "job": "Director",
#    "department": "Directing",
#    "profile_path": "/8Njf10gbKo1IMan4KgK2669xJ5K.jpg",
#    "id": 78896
#   }
#  ],
#  "vote_average": 5.6,
#  "runtime": 104
# }

# %% [markdown]
# # 3.2.3 Basic Searching

# %%
def search(query):
    url = 'http://localhost:9200/tmdb/movie/_search'
    httpResp = requests.get(url, data=json.dumps(query), headers=headers) #A
    searchHits = json.loads(httpResp.text)['hits']
    print "Num\tRelevance Score\t\tMovie Title\t\tOverview" #B
    for idx, hit in enumerate(searchHits['hits']):
            print "%s\t%s\t\t%s" % (idx + 1, hit['_score'], hit['_source']['title'])

# %%
usersSearch = 'basketball with cartoon aliens'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch, #A
            'fields': ['title^10', 'overview'], #B
        },
    },
    'size': '100'
}
search(query)
# Out:
# Num	Relevance Score		Movie Title		Overview
# 1	85.5693		Aliens
# 2	73.71077		The Basketball Diaries
# 3	71.3202		Cowboys & Aliens
# 4	61.13922		Monsters vs Aliens
# 5	53.501823		Aliens in the Attic
# 6	53.501823		Aliens vs Predator: Requiem
# 7	45.221092		Dances with Wolves
# 8	45.221092		Friends with Kids
# 9	45.221092		Friends with Benefits
# 10	45.221092		Fire with Fire
# 11	39.57216		From Paris with Love
# 12	39.57216		Sleeping with the Enemy
# 13	39.57216		Interview with the Vampire
# 14	39.57216		Just Go With It
# 15	39.57216		To Rome with Love
# 16	39.57216		Gone with the Wind
# 17	39.57216		My Week with Marilyn
# 18	39.57216		Hobo with a Shotgun
# 19	39.57216		From Russia With Love
# 20	39.57216		Trouble with the Curve
# 21	35.177814		Die Hard: With a Vengeance
# 22	35.177814		Fun with Dick and Jane
# 23	35.177814		Girl with a Pearl Earring
# 24	31.661877		The Girl with the Dragon Tattoo
# 25	31.661877		The Life Aquatic With Steve Zissou
# 26	31.661877		The Man with the Golden Gun
# 27	31.661877		Twin Peaks: Fire Walk with Me
# 28	31.661877		Cloudy with a Chance of Meatballs
# 29	31.661877		The Girl Who Played with Fire
# 30	31.661877		The Girl with the Dragon Tattoo
# 31	31.661877		You Don't Mess With the Zohan
# 32	31.661877		The Man with the Iron Fists
# 33	28.784897		Cloudy with a Chance of Meatballs 2
# 34	28.784897		The Pirates! In an Adventure with Scientists!
# 35	9.305035		Meet Dave
# 36	8.257416		Speed Racer
# 37	7.9753795		Space Jam
# 38	7.7324815		Grown Ups
# 39	7.505871		Semi-Pro
# 40	7.390269		The Flintstones
# 41	7.219441		Coach Carter
# 42	6.7105947		White Men Can't Jump
# 43	6.6692567		Alien: Resurrection
# 44	6.531829		Teen Wolf
# 45	6.5275307		District 9
# 46	6.4917965		Bedazzled
# 47	6.458376		The Watch
# 48	6.1556296		Galaxy Quest
# 49	5.7469673		Batteries Not Included
# 50	5.5015993		They Live
# 51	5.3065963		Pitch Black
# 52	5.129005		High School Musical
# 53	5.073344		AVP: Alien vs. Predator
# 54	4.9289107		Dude, Where’s My Car?
# 55	4.87677		Men in Black 3
# 56	4.7924733		Battlefield Earth
# 57	4.7924733		Cocoon
# 58	1.6364228		Dark City
# 59	1.6025233		Sex Drive
# 60	1.594499		The Switch
# 61	1.594499		Carrie
# 62	1.5821548		Bride of Chucky
# 63	1.5821548		Nim's Island
# 64	1.5821548		Young Adult
# 65	1.5721632		White Noise
# 66	1.5721632		Odd Thomas
# 67	1.5721632		The Guard
# 68	1.5704502		Frida
# 69	1.5546697		Guess Who
# 70	1.5525542		Silver Linings Playbook
# 71	1.5429322		Cinema Paradiso
# 72	1.5292041		The Man in the Iron Mask
# 73	1.5240412		Safe Haven
# 74	1.5240412		Wild Card
# 75	1.5240412		Strangers on a Train
# 76	1.5240412		[REC]²
# 77	1.5056072		Step Up Revolution
# 78	1.5045594		Ghosts of Girlfriends Past
# 79	1.4965564		My Big Fat Greek Wedding
# 80	1.4965564		27 Dresses
# 81	1.4925326		Armored
# 82	1.4925326		Lethal Weapon
# 83	1.4787775		Vicky Cristina Barcelona
# 84	1.4690466		Garden State
# 85	1.4690466		Mary Poppins
# 86	1.4690466		The Ant Bully
# 87	1.4690466		Days of Thunder
# 88	1.4690466		Rush Hour 3
# 89	1.461416		The Spiderwick Chronicles
# 90	1.461416		8½
# 91	1.461416		Fantastic Mr. Fox
# 92	1.4599357		Justice League: Throne of Atlantis
# 93	1.4528873		Just Friends
# 94	1.4528873		Stuart Little
# 95	1.4462883		Matilda
# 96	1.4462883		Jersey Girl
# 97	1.4444574		Submarine
# 98	1.4361249		Outlander
# 99	1.4361249		Stoker
# 100	1.4361249		Mesrine: Killer Instinct

# %% [markdown]
# # 2.3.1 Query Validation API

# %%
query = {
   'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^10', 'overview']
        }
    }
}
httpResp = requests.get('http://localhost:9200' + 
			    '/tmdb/movie/_validate/query?explain',
			     data=json.dumps(query), headers=headers)
print json.loads(httpResp.text)
# Out:
# {u'valid': True, u'explanations': [{u'index': u'tmdb', u'explanation': u'+((title:basketball title:with title:cartoon title:aliens)^10.0 | (overview:basketball overview:with overview:cartoon overview:aliens)) #*:*', u'valid': True}], u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}}

# %% [markdown]
# # 2.3.3 Debugging Analysis

# %%
# Inner Layer of the Onion -- Why did the search engine consider these movies matches? Two sides to this
# (1) What tokens are placed in the search engine?
# (2) What did the search engine attempt to match exactly?

# Explain of what's happening when we construct these terms

#resp = requests.get(elasticSearchUrl + "/tmdb/_mapping/movie/field/title?format=yaml'
data={"text":"Fire with Fire", "field":"title"}
print json.dumps(data)

resp = requests.get('http://localhost:9200/tmdb/_analyze?format=yaml', 
                    data=json.dumps(data), headers=headers)
print resp.text
# Out:
# {"text": "Fire with Fire", "field": "title"}
# ---
# tokens:
# - token: "fire"
#   start_offset: 0
#   end_offset: 4
#   type: "<ALPHANUM>"
#   position: 0
# - token: "with"
#   start_offset: 5
#   end_offset: 9
#   type: "<ALPHANUM>"
#   position: 1
# - token: "fire"
#   start_offset: 10
#   end_offset: 14
#   type: "<ALPHANUM>"
#   position: 2

# %% [markdown]
# # 2.3.5 -- Solving The Matching Problem

# %%
mappingSettings = {
       'movie': {
            'properties': {
               'title': { #A
                   'type': 'string',
                   'analyzer': 'english'
               },
            'overview': {
                   'type': 'string',
                   'analyzer': 'english'
               }
            }
       }
}
reindex(mappingSettings=mappingSettings, movieDict=movieDict)
# Out:
# building...
# indexing...

# %%
resp = requests.get('http://localhost:9200/tmdb/_analyze?format=yaml', 
                    data=json.dumps(data), headers=headers)
print resp.text
# Out:
# ---
# tokens:
# - token: "fire"
#   start_offset: 0
#   end_offset: 4
#   type: "<ALPHANUM>"
#   position: 0
# - token: "with"
#   start_offset: 5
#   end_offset: 9
#   type: "<ALPHANUM>"
#   position: 1
# - token: "fire"
#   start_offset: 10
#   end_offset: 14
#   type: "<ALPHANUM>"
#   position: 2

# %% [markdown]
# ## Repeat the search

# %%
usersSearch = 'basketball with cartoon aliens'
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch, #A
            'fields': ['title^10', 'overview'], #B
        },
    },
    'size': '100'
}
search(query)
# Out:
# Num	Relevance Score		Movie Title		Overview
# 1	1.0754712		Alien
# 2	1.0754712		Aliens
# 3	1.0754712		Alien³
# 4	1.032656		The Basketball Diaries
# 5	0.67216945		Cowboys & Aliens
# 6	0.67216945		Aliens in the Attic
# 7	0.67216945		Alien: Resurrection
# 8	0.5377356		AVP: Alien vs. Predator
# 9	0.5377356		Monsters vs Aliens
# 10	0.5377356		Aliens vs Predator: Requiem
# 11	0.08214001		Space Jam
# 12	0.024269354		Grown Ups
# 13	0.023364348		Speed Racer
# 14	0.023364348		The Flintstones
# 15	0.020802302		White Men Can't Jump
# 16	0.020802302		Coach Carter
# 17	0.018015321		Semi-Pro
# 18	0.016667001		The Thing
# 19	0.014142419		Meet Dave
# 20	0.0138682015		Teen Wolf
# 21	0.0138682015		High School Musical
# 22	0.0138682015		Bedazzled
# 23	0.013333602		Invasion of the Body Snatchers
# 24	0.013333602		Escape from Planet Earth
# 25	0.013333602		Slither
# 26	0.013333602		The Darkest Hour
# 27	0.01178535		District 9
# 28	0.011666901		Avatar
# 29	0.011666901		The Last Starfighter
# 30	0.010103833		The X Files
# 31	0.010000201		Scary Movie 3
# 32	0.010000201		The Hitchhiker's Guide to the Galaxy
# 33	0.010000201		Titan A.E.
# 34	0.010000201		Napoleon Dynamite
# 35	0.010000201		Outlander
# 36	0.010000201		The Day the Earth Stood Still
# 37	0.010000201		Galaxy Quest
# 38	0.0094282795		Dude, Where’s My Car?
# 39	0.0094282795		Star Trek IV: The Voyage Home
# 40	0.0094282795		Independence Day
# 41	0.0094282795		Ghosts of Mars
# 42	0.0094282795		Edge of Tomorrow
# 43	0.0083335005		Batteries Not Included
# 44	0.0083335005		Scary Movie 4
# 45	0.0083335005		Contact
# 46	0.0083335005		Lifted
# 47	0.0083335005		The Host
# 48	0.0083335005		Species
# 49	0.0083335005		Justice League: War
# 50	0.0083335005		The Watch
# 51	0.0083335005		Star Trek: Insurrection
# 52	0.0083335005		Predators
# 53	0.0083335005		Under the Skin
# 54	0.0083335005		Mars Attacks!
# 55	0.0083335005		Pitch Black
# 56	0.008249745		Battleship
# 57	0.008249745		Attack the Block
# 58	0.006666801		Lilo & Stitch
# 59	0.006666801		Predator
# 60	0.006666801		Spider-Man 3
# 61	0.006666801		Dreamcatcher
# 62	0.006666801		Predator 2
# 63	0.006666801		The Day the Earth Stood Still
# 64	0.006666801		Battlefield Earth
# 65	0.006666801		Riddick
# 66	0.006666801		Doom
# 67	0.006666801		Cocoon
# 68	0.006666801		Short Circuit
# 69	0.006666801		Men in Black
# 70	0.006666801		The Invasion
# 71	0.006666801		They Live
# 72	0.006666801		Halo 4: Forward Unto Dawn
# 73	0.006666801		Spring Breakers
# 74	0.006666801		Home
# 75	0.006666801		Paul
# 76	0.006666801		Monsters
# 77	0.006666801		The Faculty
# 78	0.0058334507		Men in Black 3
# 79	0.0058334507		Mars Needs Moms
# 80	0.0058334507		Pride
# 81	0.0058334507		Men in Black II
# 82	0.0058334507		There Will Be Blood
# 83	0.0050001005		Stalker
# 84	0.0050001005		Wreck-It Ralph

# %% [markdown]
# # 2.4.1	Decomposing Relevance Score With Lucene’s Explain

# %%
query['explain'] = True
httpResp = requests.get('http://localhost:9200/tmdb/movie/_search', data=json.dumps(query))
jsonResp = json.loads(httpResp.text)
print json.dumps(jsonResp['hits']['hits'][0]['_explanation'], indent=True)
print "Explain for %s" % jsonResp['hits']['hits'][0]['_source']['title']
print simplerExplain(jsonResp['hits']['hits'][0]['_explanation'])
print "Explain for %s" % jsonResp['hits']['hits'][1]['_source']['title']
print simplerExplain(jsonResp['hits']['hits'][1]['_explanation'])
print "Explain for %s" % jsonResp['hits']['hits'][2]['_source']['title']
print simplerExplain(jsonResp['hits']['hits'][2]['_explanation'])
print "Explain for %s" % jsonResp['hits']['hits'][3]['_source']['title']
print simplerExplain(jsonResp['hits']['hits'][3]['_explanation'])
print "Explain for %s" % jsonResp['hits']['hits'][10]['_source']['title']
print simplerExplain(jsonResp['hits']['hits'][10]['_explanation'])
# Out:
# {
#  "description": "sum of:",
#  "value": 1.0754712,
#  "details": [
#   {
#    "description": "max of:",
#    "value": 1.0754712,
#    "details": [
#     {
#      "description": "product of:",
#      "value": 1.0754712,
#      "details": [
#       {
#        "description": "sum of:",
#        "value": 3.2264135,
#        "details": [
#         {
#          "description": "weight(title:alien in 23) [PerFieldSimilarity], result of:",
#          "value": 3.2264135,
#          "details": [
#           {
#            "description": "score(doc=23,freq=1.0), product of:",
#            "value": 3.2264135,
#            "details": [
#             {
#              "description": "queryWeight, product of:",
#              "value": 0.48007536,
#              "details": [
#               {
#                "description": "idf(docFreq=9, maxDocs=3051)",
#                "value": 6.7206397,
#                "details": []
#               },
#               {
#                "description": "queryNorm",
#                "value": 0.071432985,
#                "details": []
#               }
#              ]
#             },
#             {
#              "description": "fieldWeight in 23, product of:",
#              "value": 6.7206397,
#              "details": [
#               {
#                "description": "tf(freq=1.0), with freq of:",
#                "value": 1.0,
#                "details": [
#                 {
#                  "description": "termFreq=1.0",
#                  "value": 1.0,
#                  "details": []
#                 }
#                ]
#               },
#               {
#                "description": "idf(docFreq=9, maxDocs=3051)",
#                "value": 6.7206397,
#                "details": []
#               },
#               {
#                "description": "fieldNorm(doc=23)",
#                "value": 1.0,
#                "details": []
#               }
#              ]
#             }
#            ]
#           }
#          ]
#         }
#        ]
#       },
#       {
#        "description": "coord(1/3)",
#        "value": 0.33333334,
#        "details": []
#       }
#      ]
#     },
#     {
#      "description": "product of:",
#      "value": 0.006666801,
#      "details": [
#       {
#        "description": "sum of:",
#        "value": 0.020000402,
#        "details": [
#         {
#          "description": "weight(overview:alien in 23) [PerFieldSimilarity], result of:",
#          "value": 0.020000402,
#          "details": [
#           {
#            "description": "score(doc=23,freq=1.0), product of:",
#            "value": 0.020000402,
#            "details": [
#             {
#              "description": "queryWeight, product of:",
#              "value": 0.033807553,
#              "details": [
#               {
#                "description": "idf(docFreq=72, maxDocs=3051)",
#                "value": 4.732765,
#                "details": []
#               },
#               {
#                "description": "queryNorm",
#                "value": 0.0071432986,
#                "details": []
#               }
#              ]
#             },
#             {
#              "description": "fieldWeight in 23, product of:",
#              "value": 0.59159565,
#              "details": [
#               {
#                "description": "tf(freq=1.0), with freq of:",
#                "value": 1.0,
#                "details": [
#                 {
#                  "description": "termFreq=1.0",
#                  "value": 1.0,
#                  "details": []
#                 }
#                ]
#               },
#               {
#                "description": "idf(docFreq=72, maxDocs=3051)",
#                "value": 4.732765,
#                "details": []
#               },
#               {
#                "description": "fieldNorm(doc=23)",
#                "value": 0.125,
#                "details": []
#               }
#              ]
#             }
#            ]
#           }
#          ]
#         }
#        ]
#       },
#       {
#        "description": "coord(1/3)",
#        "value": 0.33333334,
#        "details": []
#       }
#      ]
#     }
#    ]
#   },
#   {
#    "description": "match on required clause, product of:",
#    "value": 0.0,
#    "details": [
#     {
#      "description": "# clause",
#      "value": 0.0,
#      "details": []
#     },
#     {
#      "description": "_type:movie, product of:",
#      "value": 0.0071432986,
#      "details": [
#       {
#        "description": "boost",
#        "value": 1.0,
#        "details": []
#       },
#       {
#        "description": "queryNorm",
#        "value": 0.0071432986,
#        "details": []
#       }
#      ]
#     }
#    ]
#   }
#  ]
# }
# Explain for Alien
# 1.0754712, sum of:
#   1.0754712, max of:
#     1.0754712, product of:
#       3.2264135, sum of:
#         3.2264135, weight(title:alien in 23) [PerFieldSimilarity], result of:
#           3.2264135, score(doc=23,freq=1.0), product of:
#             0.48007536, queryWeight, product of:
#               6.7206397, idf(docFreq=9, maxDocs=3051)
#               0.071432985, queryNorm
#             6.7206397, fieldWeight in 23, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.7206397, idf(docFreq=9, maxDocs=3051)
#               1.0, fieldNorm(doc=23)
#       0.33333334, coord(1/3)
#     0.006666801, product of:
#       0.020000402, sum of:
#         0.020000402, weight(overview:alien in 23) [PerFieldSimilarity], result of:
#           0.020000402, score(doc=23,freq=1.0), product of:
#             0.033807553, queryWeight, product of:
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.0071432986, queryNorm
#             0.59159565, fieldWeight in 23, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.125, fieldNorm(doc=23)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0071432986, _type:movie, product of:
#       1.0, boost
#       0.0071432986, queryNorm
#
# Explain for Aliens
# 1.0754712, sum of:
#   1.0754712, max of:
#     1.0754712, product of:
#       3.2264135, sum of:
#         3.2264135, weight(title:alien in 518) [PerFieldSimilarity], result of:
#           3.2264135, score(doc=518,freq=1.0), product of:
#             0.48007536, queryWeight, product of:
#               6.7206397, idf(docFreq=9, maxDocs=3051)
#               0.071432985, queryNorm
#             6.7206397, fieldWeight in 518, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.7206397, idf(docFreq=9, maxDocs=3051)
#               1.0, fieldNorm(doc=518)
#       0.33333334, coord(1/3)
#     0.0083335005, product of:
#       0.025000501, sum of:
#         0.025000501, weight(overview:alien in 518) [PerFieldSimilarity], result of:
#           0.025000501, score(doc=518,freq=1.0), product of:
#             0.033807553, queryWeight, product of:
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.0071432986, queryNorm
#             0.73949456, fieldWeight in 518, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.15625, fieldNorm(doc=518)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0071432986, _type:movie, product of:
#       1.0, boost
#       0.0071432986, queryNorm
#
# Explain for Alien³
# 1.0754712, sum of:
#   1.0754712, max of:
#     1.0754712, product of:
#       3.2264135, sum of:
#         3.2264135, weight(title:alien in 1482) [PerFieldSimilarity], result of:
#           3.2264135, score(doc=1482,freq=1.0), product of:
#             0.48007536, queryWeight, product of:
#               6.7206397, idf(docFreq=9, maxDocs=3051)
#               0.071432985, queryNorm
#             6.7206397, fieldWeight in 1482, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.7206397, idf(docFreq=9, maxDocs=3051)
#               1.0, fieldNorm(doc=1482)
#       0.33333334, coord(1/3)
#     0.006666801, product of:
#       0.020000402, sum of:
#         0.020000402, weight(overview:alien in 1482) [PerFieldSimilarity], result of:
#           0.020000402, score(doc=1482,freq=1.0), product of:
#             0.033807553, queryWeight, product of:
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.0071432986, queryNorm
#             0.59159565, fieldWeight in 1482, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.125, fieldNorm(doc=1482)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0071432986, _type:movie, product of:
#       1.0, boost
#       0.0071432986, queryNorm
#
# Explain for The Basketball Diaries
# 1.032656, sum of:
#   1.032656, max of:
#     1.032656, product of:
#       3.0979676, sum of:
#         3.0979676, weight(title:basketbal in 70) [PerFieldSimilarity], result of:
#           3.0979676, score(doc=70,freq=1.0), product of:
#             0.5950423, queryWeight, product of:
#               8.330077, idf(docFreq=1, maxDocs=3051)
#               0.071432985, queryNorm
#             5.2062984, fieldWeight in 70, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               8.330077, idf(docFreq=1, maxDocs=3051)
#               0.625, fieldNorm(doc=70)
#       0.33333334, coord(1/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0071432986, _type:movie, product of:
#       1.0, boost
#       0.0071432986, queryNorm
#
# Explain for Space Jam
# 0.08214001, sum of:
#   0.08214001, max of:
#     0.08214001, product of:
#       0.12321001, sum of:
#         0.08320921, weight(overview:basketbal in 247) [PerFieldSimilarity], result of:
#           0.08320921, score(doc=247,freq=1.0), product of:
#             0.048760157, queryWeight, product of:
#               6.826, idf(docFreq=8, maxDocs=3051)
#               0.0071432986, queryNorm
#             1.7065, fieldWeight in 247, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               6.826, idf(docFreq=8, maxDocs=3051)
#               0.25, fieldNorm(doc=247)
#         0.040000804, weight(overview:alien in 247) [PerFieldSimilarity], result of:
#           0.040000804, score(doc=247,freq=1.0), product of:
#             0.033807553, queryWeight, product of:
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.0071432986, queryNorm
#             1.1831913, fieldWeight in 247, product of:
#               1.0, tf(freq=1.0), with freq of:
#                 1.0, termFreq=1.0
#               4.732765, idf(docFreq=72, maxDocs=3051)
#               0.25, fieldNorm(doc=247)
#       0.6666667, coord(2/3)
#   0.0, match on required clause, product of:
#     0.0, # clause
#     0.0071432986, _type:movie, product of:
#       1.0, boost
#       0.0071432986, queryNorm

# %% [markdown]
# # 3.4.4	Fixing Space Jam vs Alien Ranking

# %%
query = {
    'query': {
        'multi_match': { 
            'query': usersSearch,  #User's query
            'fields': ['title^0.1', 'overview'],
        }
    },
    'explain': True
}
search(query)
# Out:
# Num	Relevance Score		Movie Title		Overview
# 1	1.0016364		Space Jam
# 2	0.29594672		Grown Ups
# 3	0.28491083		Speed Racer
# 4	0.28491083		The Flintstones
# 5	0.2536686		White Men Can't Jump
# 6	0.2536686		Coach Carter
# 7	0.21968345		Semi-Pro
# 8	0.20324169		The Thing
# 9	0.1724563		Meet Dave
# 10	0.16911241		Teen Wolf
